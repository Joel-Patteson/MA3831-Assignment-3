# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm

# %%
url = "https://www.imdb.com/search/title/?groups=top_1000"

# %%
def all_page_link(start_url):
    all_urls = []
    url = start_url
    while(url != None):            #Loop around all the required webpages and terminates when last page arive!
        all_urls.append(url)
        soup = BeautifulSoup(requests.get(url).text,"html.parser")
        next_links = soup.find_all(class_='lister-page-next next-page')    #Extracts the next page link.
        if (len(next_links) == 0):         # If their is no next page, it returns 0.
            url = None
        else:
            next_page = "https://www.imdb.com" + next_links[0].get('href')
            url = next_page
    return all_urls

# %%
main_array = []
for url in tqdm(all_page_link("https://www.imdb.com/search/title/?groups=top_1000")):     #Runs the function for all the pages.
    soup = BeautifulSoup(requests.get(url).text,"html.parser")         #Extracts out the main html code.
    for link in soup.find_all(class_='lister-item-content'):
        name = link.find('a').text
        year = years = link.h3.find('span', class_='lister-item-year').text
        run_time = link.find('span',{"class":"runtime"}).text
        genre = link.find('span',{"class":"genre"}).text[1:]
        director=link.find('p',class_='').find_all('a')[0].text
        about = link.find_all('p')[1].text[5:]
        rating = imdb = float(link.strong.text)
        list_of_all = [name,year,run_time,genre,director,about,rating]
        main_array.append(list_of_all)
# Out:
# 100%|██████████| 20/20 [00:41<00:00,  2.08s/it]

# %%
index = ["movie","year","run_time","genre","director","about","rating"]

# %%
df = pd.DataFrame(main_array,columns=index)

# %%
df.head(5)
# Out:
#                            movie        year run_time  \
# 0  The Mitchells vs the Machines      (2021)  113 min
# 1   Zack Snyder's Justice League      (2021)  242 min
# 2                     The Father  (I) (2020)   97 min
# 3              Avengers: Endgame      (2019)  181 min
# 4       The Shawshank Redemption      (1994)  142 min
#
#                                       genre        director  \
# 0  Animation, Adventure, Comedy              Michael Rianda
# 1    Action, Adventure, Fantasy                 Zack Snyder
# 2                         Drama              Florian Zeller
# 3      Action, Adventure, Drama               Anthony Russo
# 4                         Drama              Frank Darabont
#
#                                                about  rating
# 0  A quirky, dysfunctional family's road trip is ...     7.8
# 1  Determined to ensure Superman's ultimate sacri...     8.1
# 2  A man refuses all assistance from his daughter...     8.3
# 3  After the devastating events of Avengers: Infi...     8.4
# 4  Two imprisoned men bond over a number of years...     9.3

# %%
df.tail()
# Out:
#                      movie    year run_time  \
# 995              Vizontele  (2001)  110 min
# 996             The Circus  (1928)   72 min
# 997                  Black  (2005)  122 min
# 998       English Vinglish  (2012)  134 min
# 999  Nefes: Vatan Sagolsun  (2009)  128 min
#
#                                    genre               director  \
# 995            Comedy, Drama                     Yilmaz Erdogan
# 996          Comedy, Romance                    Charles Chaplin
# 997                    Drama              Sanjay Leela Bhansali
# 998    Comedy, Drama, Family                       Gauri Shinde
# 999  Action, Drama, Thriller                     Levent Semerci
#
#                                                  about  rating
# 995  Lives of residents in a small Anatolian villag...     8.0
# 996  The Tramp finds work and the girl of his dream...     8.1
# 997  The cathartic tale of a young woman who can't ...     8.2
# 998  A quiet, sweet tempered housewife endures smal...     7.8
# 999  Story of 40-man Turkish task force who must de...     8.0

# %%
df['genre'] = df['genre'].str.replace(',',' ')
df['year'] = df['year'].str.extract('(\d+)').astype(int)

# %%
df.head()
# Out:
#                            movie  year run_time  \
# 0  The Mitchells vs the Machines  2021  113 min
# 1   Zack Snyder's Justice League  2021  242 min
# 2                     The Father  2020   97 min
# 3              Avengers: Endgame  2019  181 min
# 4       The Shawshank Redemption  1994  142 min
#
#                                       genre        director  \
# 0  Animation  Adventure  Comedy              Michael Rianda
# 1    Action  Adventure  Fantasy                 Zack Snyder
# 2                         Drama              Florian Zeller
# 3      Action  Adventure  Drama               Anthony Russo
# 4                         Drama              Frank Darabont
#
#                                                about  rating
# 0  A quirky, dysfunctional family's road trip is ...     7.8
# 1  Determined to ensure Superman's ultimate sacri...     8.1
# 2  A man refuses all assistance from his daughter...     8.3
# 3  After the devastating events of Avengers: Infi...     8.4
# 4  Two imprisoned men bond over a number of years...     9.3

# %%
df.to_csv('datasets\movies.csv')
